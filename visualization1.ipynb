# %%
#importing matplotlib.pyplot
import matplotlib.pyplot as plt

# %%
# %matplotlib inline

# %%
x=[-3,5,7]
y=[10,2,5]

# %%
#lineplot
fig=plt.figure(figsize=(15,3))
plt.plot(x,y)
plt.xlim(-4,10)
plt.ylim(0,12)
plt.xlabel("x axis")
plt.ylabel("y axis")
plt.title("lineplot",size=20,y=3)
plt.suptitle('sales comparison',size=50,y=2)
# Out:
# Text(0.5, 2, 'sales comparison')

# %%
fig.get_size_inches()
# Out:
# array([15.,  3.])

# %%
fig.set_size_inches(14,4)

# %%
fig

# %%
fig. ax=plt.subplots(1,1)

# %%
fig.axs=plt.subplots(2,4)

# %%
import pandas as pd
import numpy as np

# %%
#importing data
mtcars=pd.read_csv("mtcars.csv")

# %%
mtcars
# Out:
#      mpg  cyl   disp   hp  drat     wt   qsec  vs  am  gear  carb
# 0   21.0    6  160.0  110  3.90  2.620  16.46   0   1     4     4
# 1   21.0    6  160.0  110  3.90  2.875  17.02   0   1     4     4
# 2   22.8    4  108.0   93  3.85  2.320  18.61   1   1     4     1
# 3   21.4    6  258.0  110  3.08  3.215  19.44   1   0     3     1
# 4   18.7    8  360.0  175  3.15  3.440  17.02   0   0     3     2
# 5   18.1    6  225.0  105  2.76  3.460  20.22   1   0     3     1
# 6   14.3    8  360.0  245  3.21  3.570  15.84   0   0     3     4
# 7   24.4    4  146.7   62  3.69  3.190  20.00   1   0     4     2
# 8   22.8    4  140.8   95  3.92  3.150  22.90   1   0     4     2
# 9   19.2    6  167.6  123  3.92  3.440  18.30   1   0     4     4
# 10  17.8    6  167.6  123  3.92  3.440  18.90   1   0     4     4
# 11  16.4    8  275.8  180  3.07  4.070  17.40   0   0     3     3
# 12  17.3    8  275.8  180  3.07  3.730  17.60   0   0     3     3
# ...

# %%
pd.crosstab(mtcars.gear,mtcars.cyl)
# Out:
# cyl   4  6   8
# gear
# 3     1  2  12
# 4     8  4   0
# 5     2  1   2

# %%
pd.crosstab(mtcars.gear,mtcars.cyl).plot(kind="bar")
# Out:
# <AxesSubplot:xlabel='gear'>

# %%
mtcars["cyl"].value_counts()
# Out:
# 8    14
# 4    11
# 6     7
# Name: cyl, dtype: int64

# %%
mtcars["gear"].value_counts()
# Out:
# 3    15
# 4    12
# 5     5
# Name: gear, dtype: int64

# %%
mtcars.gear.value_counts().plot(kind="pie")
# Out:
# <AxesSubplot:ylabel='gear'>

# %%
import seaborn as sns

# %%
sns.boxplot(x="gear",y="mpg",data=mtcars)
# Out:
# <AxesSubplot:xlabel='gear', ylabel='mpg'>

# %%
sns.pairplot(mtcars.iloc[:,0:12])

# %%
#scatter plot
plt.scatter(mtcars.drat,mtcars.qsec)

# %%
#boxplot
plt.boxplot(mtcars.mpg,vert=False)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x2883e034e80>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x2883eec2580>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x2883e034b20>],
#  'medians': [<matplotlib.lines.Line2D at 0x2883eec2c40>],
#  'fliers': [<matplotlib.lines.Line2D at 0x2883eec2fa0>],
#  'means': []}

# %%
#Histogram
plt.hist(mtcars.mpg)
# Out:
# (array([2., 4., 6., 6., 5., 3., 1., 1., 2., 2.]),
#  array([10.4 , 12.75, 15.1 , 17.45, 19.8 , 22.15, 24.5 , 26.85, 29.2 ,
#         31.55, 33.9 ]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(mtcars.mpg,facecolor="red",edgecolor="blue",bins=40)
# Out:
# (array([2., 0., 0., 0., 1., 0., 1., 2., 3., 1., 1., 1., 1., 1., 3., 1., 0.,
#         0., 5., 0., 0., 2., 0., 1., 0., 0., 1., 0., 1., 0., 0., 0., 0., 0.,
#         2., 0., 0., 1., 0., 1.]),
#  array([10.4   , 10.9875, 11.575 , 12.1625, 12.75  , 13.3375, 13.925 ,
#         14.5125, 15.1   , 15.6875, 16.275 , 16.8625, 17.45  , 18.0375,
#         18.625 , 19.2125, 19.8   , 20.3875, 20.975 , 21.5625, 22.15  ,
#         22.7375, 23.325 , 23.9125, 24.5   , 25.0875, 25.675 , 26.2625,
#         26.85  , 27.4375, 28.025 , 28.6125, 29.2   , 29.7875, 30.375 ,
#         30.9625, 31.55  , 32.1375, 32.725 , 33.3125, 33.9   ]),
#  <BarContainer object of 40 artists>)

# %%
#violinplot
plt.violinplot(mtcars.mpg)
# Out:
# {'bodies': [<matplotlib.collections.PolyCollection at 0x28840068d60>],
#  'cmaxes': <matplotlib.collections.LineCollection at 0x28840068bb0>,
#  'cmins': <matplotlib.collections.LineCollection at 0x2884007a250>,
#  'cbars': <matplotlib.collections.LineCollection at 0x28840068fd0>}

# %%
df=pd.DataFrame(index=['Atiya', 'Abbas', 'Cornelia','Stephanie', 'Monte'],
                   data={'Apples':[20, 10, 40, 20, 50],'Oranges':[35, 40, 25, 19, 33]})

# %%
df
# Out:
#            Apples  Oranges
# Atiya          20       35
# Abbas          10       40
# Cornelia       40       25
# Stephanie      20       19
# Monte          50       33

# %%
ax=df.plot.bar(color=['.7','.5'],figsize=(15,4))

# %%
#densityplot
ax=df.plot.kde(color=[".7",".3"],figsize=(15,4))

# %%
df,(ax1,ax2,ax3)=plt.subplots(1,3,figsize=(16,4))

# %%
#subplots (lineplot,scatterplot,barplot)
fig, (ax1, ax2, ax3) = plt.subplots(1, 3, figsize=(16,4))
fig.suptitle('Two Variable Plots')
df.plot.line(ax=ax1, title='Line plot')
df.plot.scatter(x='Apples', y='Oranges',ax=ax2, title='Scatterplot')
df.plot.bar(ax=ax3, title='Bar plot')
# Out:
# <AxesSubplot:title={'center':'Bar plot'}>
